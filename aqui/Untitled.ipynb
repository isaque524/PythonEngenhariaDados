# %%
from platform import python_version
print('Versão da linguagem python', python_version())
# Out:
# Versão da linguagem python 3.9.13

# %%
# !pip install -q pandas==1.5.3

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
dados = {'Estado': ['Santa Catarina', 'Rio de Janeiro', 'Tocantis', 'Bahia', 'Minas Gerais'],
         'Ano':[2004,2005,2006,2007,20008],
        'Taxa Desemprego':[1.5, 1.7, 1.6, 2.4, 2.7]}

# %%
print(dados)
# Out:
# {'Estado': ['Santa Catarina', 'Rio de Janeiro', 'Tocantis', 'Bahia', 'Minas Gerais'], 'Ano': [2004, 2005, 2006, 2007, 20008], 'Taxa Desemprego': [1.5, 1.7, 1.6, 2.4, 2.7]}

# %%
from pandas import DataFrame

# %%
df = DataFrame(dados)

# %%
df.head()
# Out:
#            Estado    Ano  Taxa Desemprego
# 0  Santa Catarina   2004              1.5
# 1  Rio de Janeiro   2005              1.7
# 2        Tocantis   2006              1.6
# 3           Bahia   2007              2.4
# 4    Minas Gerais  20008              2.7

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
DataFrame(dados,columns = ['Estado', 'Taxa Desemprego', 'Ano'])
# Out:
#            Estado  Taxa Desemprego    Ano
# 0  Santa Catarina              1.5   2004
# 1  Rio de Janeiro              1.7   2005
# 2        Tocantis              1.6   2006
# 3           Bahia              2.4   2007
# 4    Minas Gerais              2.7  20008

# %%
df2 = DataFrame(dados,
                columns = ['Estado', 'Taxa Desemprego', 'Taxa Crecimento', 'Ano'],
                index = ['Estado1','Estado2','Estado3','Estado4','Estado5'])

# %%
df2
# Out:
#                  Estado  Taxa Desemprego Taxa Crecimento    Ano
# Estado1  Santa Catarina              1.5             NaN   2004
# Estado2  Rio de Janeiro              1.7             NaN   2005
# Estado3        Tocantis              1.6             NaN   2006
# Estado4           Bahia              2.4             NaN   2007
# Estado5    Minas Gerais              2.7             NaN  20008

# %%
df2.values
# Out:
# array([['Santa Catarina', 1.5, nan, 2004],
#        ['Rio de Janeiro', 1.7, nan, 2005],
#        ['Tocantis', 1.6, nan, 2006],
#        ['Bahia', 2.4, nan, 2007],
#        ['Minas Gerais', 2.7, nan, 20008]], dtype=object)

# %%
df2.columns
# Out:
# Index(['Estado', 'Taxa Desemprego', 'Taxa Crecimento', 'Ano'], dtype='object')

# %%
df2.dtypes
# Out:
# Estado              object
# Taxa Desemprego    float64
# Taxa Crecimento     object
# Ano                  int64
# dtype: object

# %%
df2.index
# Out:
# Index(['Estado1', 'Estado2', 'Estado3', 'Estado4', 'Estado5'], dtype='object')

# %%
df2.filter(items = ['Estado3'], axis = 0)
# Out:
#            Estado  Taxa Desemprego Taxa Crecimento   Ano
# Estado3  Tocantis              1.6             NaN  2006

# %%
df2.head()
# Out:
#                  Estado  Taxa Desemprego Taxa Crecimento    Ano
# Estado1  Santa Catarina              1.5             NaN   2004
# Estado2  Rio de Janeiro              1.7             NaN   2005
# Estado3        Tocantis              1.6             NaN   2006
# Estado4           Bahia              2.4             NaN   2007
# Estado5    Minas Gerais              2.7             NaN  20008

# %%
import numpy as np

# %%
df2['Taxa Crecimento'] = np.arange(5.)

# %%
df2
# Out:
#                  Estado  Taxa Desemprego  Taxa Crecimento    Ano
# Estado1  Santa Catarina              1.5              0.0   2004
# Estado2  Rio de Janeiro              1.7              1.0   2005
# Estado3        Tocantis              1.6              2.0   2006
# Estado4           Bahia              2.4              3.0   2007
# Estado5    Minas Gerais              2.7              4.0  20008

# %%
df2.describe()
# Out:
#        Taxa Desemprego  Taxa Crecimento           Ano
# count         5.000000         5.000000      5.000000
# mean          1.980000         2.000000   5606.000000
# std           0.535724         1.581139   8050.962831
# min           1.500000         0.000000   2004.000000
# 25%           1.600000         1.000000   2005.000000
# 50%           1.700000         2.000000   2006.000000
# 75%           2.400000         3.000000   2007.000000
# max           2.700000         4.000000  20008.000000

# %%
dsa_df = pd.read_csv("dataset.csv")

# %%
dsa_df.head(5)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %%
dsa_df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      2
# dtype: int64

# %%
moda = dsa_df['Quantidade'].value_counts().index[0]

# %%
print(moda)
# Out:
# 3.0

# %%
dsa_df['Quantidade'].fillna(value = moda, inplace = True)

# %%
dsa_df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      0
# dtype: int64

# %%
dsa_df.head(15)
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 0   CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 1   CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 2   CA-2016-138688  2016-06-12   DV-13045    Corporate  United States
# 3   US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 4   US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 6   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 7   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 8   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10  CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 11  CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# ...

# %%
dsa_df.Valor_Venda.describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
df2 = dsa_df.query('229 < Valor_Venda < 10000')

# %%
df2.Valor_Venda.describe()
# Out:
# count    2357.000000
# mean      766.679142
# std       856.315136
# min       229.544000
# 25%       323.100000
# 50%       490.320000
# 75%       859.200000
# max      9892.740000
# Name: Valor_Venda, dtype: float64

# %%
df3 = df2.query('Valor_Venda > 766')

# %%
df3.head()
# Out:
#          ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 3   US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 7   CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 10  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 11  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 24  CA-2015-106320  2015-09-25   EB-13870  Consumer  United States   West
#
#          ID_Produto   Categoria  \
# 3   FUR-TA-10000577   Furniture
# 7   TEC-PH-10002275  Technology
# 10  FUR-TA-10001539   Furniture
# 11  TEC-PH-10002033  Technology
# 24  FUR-TA-10000577   Furniture
#
#                                      Nome_Produto  Valor_Venda  Quantidade
# 3   Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 7                  Mitel 5320 IP Phone VoIP phone     907.1520         6.0
# 10       Chromcraft Rectangular Conference Tables    1706.1840         9.0
# ...

# %%
dsa_df[dsa_df['Quantidade'].isin([5,7,9,11])]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14    US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# ...              ...         ...        ...          ...            ...
# 9974  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9977  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9981  CA-2017-163566  2017-08-03   TB-21055     Consumer  United States
# 9982  US-2016-157728  2016-09-22   RC-19960     Consumer  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
#
#        Regiao       ID_Produto        Categoria  \
# 3       South  FUR-TA-10000577        Furniture
# ...

# %%
dsa_df
# Out:
#            ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0     CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1     CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2     CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3     US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4     US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# ...              ...         ...        ...        ...            ...    ...
# 9989  CA-2014-110422  2014-01-21   TB-21400   Consumer  United States  South
# 9990  CA-2017-121258  2017-02-26   DB-13060   Consumer  United States   West
# 9991  CA-2017-121258  2017-02-26   DB-13060   Consumer  United States   West
# 9992  CA-2017-121258  2017-02-26   DB-13060   Consumer  United States   West
# 9993  CA-2017-119914  2017-05-04   CC-12220   Consumer  United States   West
#
#            ID_Produto        Categoria  \
# ...

# %%
dsa_df[dsa_df.Segmento.str.startswith('Hom')].head()
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 14  US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 15  US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 34  CA-2017-107727  2017-10-19   MA-17560  Home Office  United States
# 37  CA-2015-117415  2015-12-27   SN-20710  Home Office  United States
# 38  CA-2015-117415  2015-12-27   SN-20710  Home Office  United States
#
#      Regiao       ID_Produto        Categoria  \
# 14  Central  OFF-AP-10002311  Office Supplies
# 15  Central  OFF-BI-10000756  Office Supplies
# 34  Central  OFF-PA-10000249  Office Supplies
# 37  Central  OFF-EN-10002986  Office Supplies
# 38  Central  FUR-BO-10002545        Furniture
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 14  Holmes Replacement Filter for HEPA Air Cleaner...      68.8100         5.0
# 15   Storex DuraTech Recycled Plastic Frosted Binders       2.5440         3.0
# ...

# %%
dsa_df.ID_Cliente.value_counts()
# Out:
# WB-21850    37
# JL-15835    34
# MA-17560    34
# PP-18955    34
# CK-12205    32
#             ..
# LD-16855     1
# AO-10810     1
# CJ-11875     1
# RE-19405     1
# JR-15700     1
# Name: ID_Cliente, Length: 793, dtype: int64

# %%
dsa_df[dsa_df.ID_Cliente.str.startswith('WB-')].head()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 2133  CA-2015-122210  2015-11-30   WB-21850  Consumer  United States   East
# 2134  CA-2015-122210  2015-11-30   WB-21850  Consumer  United States   East
# 2135  CA-2015-122210  2015-11-30   WB-21850  Consumer  United States   East
# 2148  CA-2014-141607  2014-12-12   WB-21850  Consumer  United States   West
# 3741  CA-2016-137848  2016-01-15   WB-21850  Consumer  United States   East
#
#            ID_Produto        Categoria  \
# 2133  OFF-BI-10003656  Office Supplies
# 2134  OFF-FA-10000053  Office Supplies
# 2135  TEC-PH-10002807       Technology
# 2148  FUR-FU-10003975        Furniture
# 3741  OFF-EN-10001137  Office Supplies
#
#                                            Nome_Produto  Valor_Venda  \
# 2133        Fellowes PB200 Plastic Comb Binding Machine      152.991
# 2134                Revere Boxed Rubber Bands by Revere       10.584
# ...

# %%
dsa_df[dsa_df.ID_Cliente.str.startswith('HP-')].head()
# Out:
#           ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 14   US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 15   US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 397  CA-2015-122259  2015-10-31   HP-14815  Home Office  United States
# 879  CA-2017-111689  2017-11-30   HP-14815  Home Office  United States
# 880  CA-2017-111689  2017-11-30   HP-14815  Home Office  United States
#
#       Regiao       ID_Produto        Categoria  \
# 14   Central  OFF-AP-10002311  Office Supplies
# 15   Central  OFF-BI-10000756  Office Supplies
# 397  Central  OFF-SU-10002573  Office Supplies
# 879     East  OFF-BI-10003984  Office Supplies
# 880     East  FUR-CH-10004287        Furniture
#
#                                           Nome_Produto  Valor_Venda  \
# 14   Holmes Replacement Filter for HEPA Air Cleaner...       68.810
# 15    Storex DuraTech Recycled Plastic Frosted Binders        2.544
# ...

# %%
# !pip install -q scikit-learn==1.2.1

# %%
import sklearn
sklearn.__version__
# Out:
# '1.2.1'

# %%
from sklearn.datasets import load_iris
data = load_iris()

# %%
import pandas as pd
df = pd.DataFrame(data['data'], columns = data['feature_names'])
df['species'] = data['target']
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x = 'sepal length (cm)', y = 'sepal width (cm)' )
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal width (cm)'>
